# %% [markdown]
# <a href="https://colab.research.google.com/github/h8erqqq/ML/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1_Korovin_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ca_offenses_by_agency.csv")
df
# Out:
#     State/Tribal/Other                              Agency Unit/Office  \
# 0       State Agencies          Atascadero State Hospital4         NaN
# 1       State Agencies              California State Fair4         NaN
# 2       State Agencies             Coalinga State Hospital         NaN
# 3       State Agencies  Department of Parks and Recreation     Angeles
# 4       State Agencies  Department of Parks and Recreation    Bay Area
# ..                 ...                                 ...         ...
# 228                NaN                                 NaN         NaN
# 229                NaN                                 NaN         NaN
# 230                NaN                                 NaN         NaN
# 231                NaN                                 NaN         NaN
# 232                NaN                                 NaN         NaN
#
#      Violent crime  Murder and nonnegligent manslaughter  \
# 0            321.0                                   0.0
# 1             12.0                                   0.0
# 2            149.0                                   0.0
# 3              2.0                                   0.0
# 4              0.0                                   0.0
# ..             ...                                   ...
# 228            NaN                                   NaN
# 229            NaN                                   NaN
# 230            NaN                                   NaN
# 231            NaN                                   NaN
# 232            NaN                                   NaN
#
#      Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                          0.0                       NaN      0.0
# 1                          0.0                       NaN      0.0
# 2                          0.0                       NaN      0.0
# 3                          0.0                       NaN      1.0
# 4                          0.0                       NaN      0.0
# ..                         ...                       ...      ...
# 228                        NaN                       NaN      NaN
# 229                        NaN                       NaN      NaN
# 230                        NaN                       NaN      NaN
# 231                        NaN                       NaN      NaN
# 232                        NaN                       NaN      NaN
#
#      Aggravated assault Property crime  Burglary Larceny-theft  \
# 0                 321.0              4       0.0             2
# 1                  12.0             79      21.0            56
# 2                 149.0              3       1.0             2
# 3                   1.0             26       8.0            18
# 4                   0.0              1       0.0             0
# ..                  ...            ...       ...           ...
# 228                 NaN            NaN       NaN           NaN
# 229                 NaN            NaN       NaN           NaN
# 230                 NaN            NaN       NaN           NaN
# 231                 NaN            NaN       NaN           NaN
# 232                 NaN            NaN       NaN           NaN
#
#     Motor vehicle theft  Arson
# 0                     2    0.0
# 1                     2    1.0
# 2                     0    0.0
# 3                     0    0.0
# 4                     1    0.0
# ..                  ...    ...
# 228                 NaN    NaN
# 229                 NaN    NaN
# 230                 NaN    NaN
# 231                 NaN    NaN
# 232                 NaN    NaN
#
# [233 rows x 14 columns]

# %%
# фикс
from numpy import nan

def convert_to_float(df, column_name):
    # Convert the column to string, replace non-numeric values and NaN with empty strings, then convert to float
    df[column_name] = df[column_name].astype(str).str.replace('[^0-9.]', '', regex=True).replace('', nan).astype(float)
    return df[column_name]

# Example for replace the column dtype
df['Violent crime'] = convert_to_float(df, 'Violent crime')
df['Motor vehicle theft'] = convert_to_float(df, 'Motor vehicle theft')
df['Motor vehicle theft']
# Out:
# 0      2.0
# 1      2.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 228    NaN
# 229    NaN
# 230    NaN
# 231    NaN
# 232    NaN
# Name: Motor vehicle theft, Length: 233, dtype: float64

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.columns
# Out:
# Index(['State/Tribal/Other', 'Agency', 'Unit/Office', 'Violent crime',
#        'Murder and nonnegligent manslaughter', 'Rape (revised definition)',
#        'Rape (legacy definition)', 'Robbery', 'Aggravated assault',
#        'Property crime', 'Burglary', 'Larceny-theft', 'Motor vehicle theft',
#        'Arson'],
#       dtype='object')

# %%
#Первые 5 значений
df.head()
# Out:
#   State/Tribal/Other                              Agency Unit/Office  \
# 0     State Agencies          Atascadero State Hospital4         NaN
# 1     State Agencies              California State Fair4         NaN
# 2     State Agencies             Coalinga State Hospital         NaN
# 3     State Agencies  Department of Parks and Recreation     Angeles
# 4     State Agencies  Department of Parks and Recreation    Bay Area
#
#    Violent crime  Murder and nonnegligent manslaughter  \
# 0          321.0                                   0.0
# 1           12.0                                   0.0
# 2          149.0                                   0.0
# 3            2.0                                   0.0
# 4            0.0                                   0.0
#
#    Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                        0.0                       NaN      0.0
# 1                        0.0                       NaN      0.0
# 2                        0.0                       NaN      0.0
# 3                        0.0                       NaN      1.0
# 4                        0.0                       NaN      0.0
#
#    Aggravated assault Property crime  Burglary Larceny-theft  \
# 0               321.0              4       0.0             2
# 1                12.0             79      21.0            56
# 2               149.0              3       1.0             2
# 3                 1.0             26       8.0            18
# 4                 0.0              1       0.0             0
#
#   Motor vehicle theft  Arson
# 0                   2    0.0
# 1                   2    1.0
# 2                   0    0.0
# 3                   0    0.0
# 4                   1    0.0

# %%
#Последние 5 значений
df.tail()
# Out:
#     State/Tribal/Other Agency Unit/Office  Violent crime  \
# 228                NaN    NaN         NaN            NaN
# 229                NaN    NaN         NaN            NaN
# 230                NaN    NaN         NaN            NaN
# 231                NaN    NaN         NaN            NaN
# 232                NaN    NaN         NaN            NaN
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 228                                   NaN                        NaN
# 229                                   NaN                        NaN
# 230                                   NaN                        NaN
# 231                                   NaN                        NaN
# 232                                   NaN                        NaN
#
#      Rape (legacy definition)  Robbery  Aggravated assault Property crime  \
# 228                       NaN      NaN                 NaN            NaN
# 229                       NaN      NaN                 NaN            NaN
# 230                       NaN      NaN                 NaN            NaN
# 231                       NaN      NaN                 NaN            NaN
# 232                       NaN      NaN                 NaN            NaN
#
#      Burglary Larceny-theft Motor vehicle theft  Arson
# 228       NaN           NaN                 NaN    NaN
# 229       NaN           NaN                 NaN    NaN
# 230       NaN           NaN                 NaN    NaN
# 231       NaN           NaN                 NaN    NaN
# 232       NaN           NaN                 NaN    NaN

# %%
#Статистику
df.describe()
# Out:
#        Violent crime  Murder and nonnegligent manslaughter  \
# count     169.000000                            169.000000
# mean       15.976331                              0.041420
# std        81.072642                              0.295905
# min         0.000000                              0.000000
# 25%         0.000000                              0.000000
# 50%         0.000000                              0.000000
# 75%         2.000000                              0.000000
# max       803.000000                              3.000000
#
#        Rape (revised definition)  Rape (legacy definition)     Robbery  \
# count                 169.000000                       0.0  169.000000
# mean                    0.201183                       NaN    4.112426
# std                     0.916644                       NaN   31.098238
# min                     0.000000                       NaN    0.000000
# 25%                     0.000000                       NaN    0.000000
# 50%                     0.000000                       NaN    0.000000
# 75%                     0.000000                       NaN    0.000000
# max                     8.000000                       NaN  387.000000
#
#        Aggravated assault    Burglary       Arson
# count          169.000000  169.000000  167.000000
# mean            11.621302    5.668639    0.281437
# std             60.029644   20.991983    1.140103
# min              0.000000    0.000000    0.000000
# 25%              0.000000    0.000000    0.000000
# 50%              0.000000    0.000000    0.000000
# 75%              2.000000    2.000000    0.000000
# max            559.000000  178.000000    8.000000

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %%
df.mean()
# Out:
# <ipython-input-12-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Violent crime                           15.976331
# Murder and nonnegligent manslaughter     0.041420
# Rape (revised definition)                0.201183
# Rape (legacy definition)                      NaN
# Robbery                                  4.112426
# Aggravated assault                      11.621302
# Burglary                                 5.668639
# Arson                                    0.281437
# dtype: float64

# %% [markdown]
# 1.   **Ответ 1.**
# 2.   **Ответ 2.**

# %%
df.min()
# Out:
# <ipython-input-13-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Violent crime                           0.0
# Murder and nonnegligent manslaughter    0.0
# Rape (revised definition)               0.0
# Rape (legacy definition)                NaN
# Robbery                                 0.0
# Aggravated assault                      0.0
# Burglary                                0.0
# Arson                                   0.0
# dtype: float64

# %%
df.max()
# Out:
# <ipython-input-14-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Violent crime                           803.0
# Murder and nonnegligent manslaughter      3.0
# Rape (revised definition)                 8.0
# Rape (legacy definition)                  NaN
# Robbery                                 387.0
# Aggravated assault                      559.0
# Burglary                                178.0
# Arson                                     8.0
# dtype: float64

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df["State/Tribal/Other"] = df["State/Tribal/Other"].astype("category")
df["Burglary"] = df["Burglary"].astype("float")
df["Motor vehicle theft"] = df["Motor vehicle theft"].astype("float")
#Вывести типы колонок тут
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   State/Tribal/Other                    169 non-null    category
#  1   Agency                                169 non-null    object
#  2   Unit/Office                           143 non-null    object
#  3   Violent crime                         169 non-null    float64
#  4   Murder and nonnegligent manslaughter  169 non-null    float64
#  5   Rape (revised definition)             169 non-null    float64
#  6   Rape (legacy definition)              0 non-null      float64
#  7   Robbery                               169 non-null    float64
#  8   Aggravated assault                    169 non-null    float64
#  9   Property crime                        169 non-null    object
#  10  Burglary                              169 non-null    float64
#  11  Larceny-theft                         169 non-null    object
#  12  Motor vehicle theft                   169 non-null    float64
#  13  Arson                                 167 non-null    float64
# dtypes: category(1), float64(9), object(4)
# memory usage: 24.1+ KB

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[df["Aggravated assault"]>50]
# Out:
#     State/Tribal/Other                                      Agency  \
# 0       State Agencies                  Atascadero State Hospital4
# 2       State Agencies                     Coalinga State Hospital
# 90      State Agencies                        Napa State Hospital4
# 91      State Agencies                      Patton State Hospital4
# 106     Other Agencies  Los Angeles Transportation Services Bureau
# 108     Other Agencies                   Port of San Diego Harbor4
#
#     Unit/Office  Violent crime  Murder and nonnegligent manslaughter  \
# 0           NaN          321.0                                   0.0
# 2           NaN          149.0                                   0.0
# 90          NaN          125.0                                   0.0
# 91          NaN          566.0                                   0.0
# 106         NaN          803.0                                   3.0
# 108         NaN           87.0                                   1.0
#
#      Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                          0.0                       NaN      0.0
# 2                          0.0                       NaN      0.0
# 90                         1.0                       NaN      0.0
# 91                         7.0                       NaN      0.0
# 106                        8.0                       NaN    387.0
# 108                        2.0                       NaN     10.0
#
#      Aggravated assault Property crime  Burglary Larceny-theft  \
# 0                 321.0              4       0.0             2
# 2                 149.0              3       1.0             2
# 90                124.0              7       3.0             4
# 91                559.0              9       4.0             5
# 106               405.0          1,088      11.0           939
# 108                74.0            569      53.0           513
#
#      Motor vehicle theft  Arson
# 0                    2.0    0.0
# 2                    0.0    0.0
# 90                   0.0    0.0
# 91                   0.0    0.0
# 106                138.0    6.0
# 108                  3.0    2.0

# %%
#Фильтр колонки 2
df[df["State/Tribal/Other"]=='State Agencies']
# Out:
#    State/Tribal/Other                              Agency   Unit/Office  \
# 0      State Agencies          Atascadero State Hospital4           NaN
# 1      State Agencies              California State Fair4           NaN
# 2      State Agencies             Coalinga State Hospital           NaN
# 3      State Agencies  Department of Parks and Recreation       Angeles
# 4      State Agencies  Department of Parks and Recreation      Bay Area
# ..                ...                                 ...           ...
# 89     State Agencies                      Highway Patrol  Yuba County4
# 90     State Agencies                Napa State Hospital4           NaN
# 91     State Agencies              Patton State Hospital4           NaN
# 92     State Agencies   Porterville Developmental Center4           NaN
# 93     State Agencies         Sonoma Developmental Center           NaN
#
#     Violent crime  Murder and nonnegligent manslaughter  \
# 0           321.0                                   0.0
# 1            12.0                                   0.0
# 2           149.0                                   0.0
# 3             2.0                                   0.0
# 4             0.0                                   0.0
# ..            ...                                   ...
# 89            0.0                                   0.0
# 90          125.0                                   0.0
# 91          566.0                                   0.0
# 92           10.0                                   0.0
# 93            6.0                                   0.0
#
#     Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 0                         0.0                       NaN      0.0
# 1                         0.0                       NaN      0.0
# 2                         0.0                       NaN      0.0
# 3                         0.0                       NaN      1.0
# 4                         0.0                       NaN      0.0
# ..                        ...                       ...      ...
# 89                        0.0                       NaN      0.0
# 90                        1.0                       NaN      0.0
# 91                        7.0                       NaN      0.0
# 92                        1.0                       NaN      0.0
# 93                        0.0                       NaN      0.0
#
#     Aggravated assault Property crime  Burglary Larceny-theft  \
# 0                321.0              4       0.0             2
# 1                 12.0             79      21.0            56
# 2                149.0              3       1.0             2
# 3                  1.0             26       8.0            18
# 4                  0.0              1       0.0             0
# ..                 ...            ...       ...           ...
# 89                 0.0            254       0.0            14
# 90               124.0              7       3.0             4
# 91               559.0              9       4.0             5
# 92                 9.0             14       4.0            10
# 93                 6.0              2       0.0             2
#
#     Motor vehicle theft  Arson
# 0                   2.0    0.0
# 1                   2.0    1.0
# 2                   0.0    0.0
# 3                   0.0    0.0
# 4                   1.0    0.0
# ..                  ...    ...
# 89                240.0    0.0
# 90                  0.0    0.0
# 91                  0.0    0.0
# 92                  0.0    0.0
# 93                  0.0    0.0
#
# [94 rows x 14 columns]

# %%
#Фильтр колонки 3
df[df['Murder and nonnegligent manslaughter']>1]
# Out:
#     State/Tribal/Other                                      Agency  \
# 102     Other Agencies                     East Bay Regional Parks
# 106     Other Agencies  Los Angeles Transportation Services Bureau
#
#          Unit/Office  Violent crime  Murder and nonnegligent manslaughter  \
# 102  Alameda County4            9.0                                   2.0
# 106              NaN          803.0                                   3.0
#
#      Rape (revised definition)  Rape (legacy definition)  Robbery  \
# 102                        3.0                       NaN      2.0
# 106                        8.0                       NaN    387.0
#
#      Aggravated assault Property crime  Burglary Larceny-theft  \
# 102                 2.0            195       0.0           188
# 106               405.0          1,088      11.0           939
#
#      Motor vehicle theft  Arson
# 102                  7.0    5.0
# 106                138.0    6.0

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby(["State/Tribal/Other"]).mean()
# Out:
# <ipython-input-25-5931e37dbefa>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["State/Tribal/Other"]).mean()
#                     Violent crime  Murder and nonnegligent manslaughter  \
# State/Tribal/Other
# Other Agencies          19.514706                              0.102941
# State Agencies          14.095745                              0.000000
# Tribal Agencies          6.857143                              0.000000
#
#                     Rape (revised definition)  Rape (legacy definition)  \
# State/Tribal/Other
# Other Agencies                       0.338235                       NaN
# State Agencies                       0.106383                       NaN
# Tribal Agencies                      0.142857                       NaN
#
#                      Robbery  Aggravated assault   Burglary  \
# State/Tribal/Other
# Other Agencies      9.838235            9.235294  10.279412
# State Agencies      0.106383           13.882979   2.393617
# Tribal Agencies     2.285714            4.428571   4.857143
#
#                     Motor vehicle theft     Arson
# State/Tribal/Other
# Other Agencies                12.823529  0.588235
# State Agencies               123.755319  0.074468
# Tribal Agencies                4.142857  0.000000

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
import statistics
from collections import defaultdict

dick = defaultdict(list)

df.groupby('State/Tribal/Other').agg(['median', 'mean'])
newdf = df[['State/Tribal/Other','Robbery']].dropna()

for i, j in newdf.iterrows():
    agency = j[0]
    robbery = j[1]

    dick[agency].append(robbery)

for k, v in dick.items():
    print(f'{k} - Медиана: {statistics.median(v)}, Среднее: {statistics.mean(v)}')
# Out:
# State Agencies - Медиана: 0.0, Среднее: 0.10638297872340426
# Tribal Agencies - Медиана: 2.0, Среднее: 2.2857142857142856
# Other Agencies - Медиана: 0.0, Среднее: 9.838235294117647
# <ipython-input-30-6dcdba56aeeb>:7: FutureWarning: ['Agency', 'Unit/Office', 'Property crime', 'Larceny-theft'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('State/Tribal/Other').agg(['median', 'mean'])
